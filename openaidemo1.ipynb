# %%
print("Hello")
# Out:
# Hello

# %%
# installing the library
import os
import openai
from dotenv import load_dotenv

# %%
# check version of package
# !pip show openai
# Out:
# Name: openai
# Version: 0.28.0
# Summary: Python client library for the OpenAI API
# Home-page: https://github.com/openai/openai-python
# Author: OpenAI
# Author-email: support@openai.com
# License:
# Location: C:\Users\PUJA KUMARI\anaconda3\envs\openai\Lib\site-packages
# Requires: aiohttp, requests, tqdm
# Required-by:

# %%
# set openai api key
load_dotenv()
OPENAI_API_KEY=os.getenv("OPENAI_API_KEY")

# %%
#OPENAI_API_KEY

# %%
# that  openai key pass here (set the key inside my environment)
openai.api_key=OPENAI_API_KEY

# %%
# list of models
openai.Model.list()
# Out:
# <OpenAIObject list at 0x1e6d938b7f0> JSON: {
#   "object": "list",
#   "data": [
#     {
#       "id": "gpt-4-turbo",
#       "object": "model",
#       "created": 1712361441,
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-4-turbo-2024-04-09",
#       "object": "model",
#       "created": 1712601677,
#       "owned_by": "system"
#     },
#     {
#       "id": "tts-1",
#       "object": "model",
#       "created": 1681940951,
#       "owned_by": "openai-internal"
#     },
#     {
#       "id": "tts-1-1106",
#       "object": "model",
#       "created": 1699053241,
#       "owned_by": "system"
#     },
#     {
#       "id": "chatgpt-4o-latest",
#       "object": "model",
#       "created": 1723515131,
#       "owned_by": "system"
#     },
#     {
#       "id": "dall-e-2",
#       "object": "model",
#       "created": 1698798177,
#       "owned_by": "system"
#     },
#     {
#       "id": "whisper-1",
#       "object": "model",
#       "created": 1677532384,
#       "owned_by": "openai-internal"
#     },
#     {
#       "id": "gpt-3.5-turbo-instruct",
#       "object": "model",
#       "created": 1692901427,
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-4o-mini",
#       "object": "model",
#       "created": 1721172741,
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-4o-2024-05-13",
#       "object": "model",
#       "created": 1715368132,
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-3.5-turbo",
#       "object": "model",
#       "created": 1677610602,
#       "owned_by": "openai"
#     },
#     {
#       "id": "gpt-3.5-turbo-0125",
#       "object": "model",
#       "created": 1706048358,
#       "owned_by": "system"
#     },
#     {
#       "id": "babbage-002",
#       "object": "model",
#       "created": 1692634615,
#       "owned_by": "system"
#     },
#     {
#       "id": "davinci-002",
#       "object": "model",
#       "created": 1692634301,
#       "owned_by": "system"
#     },
#     {
#       "id": "dall-e-3",
#       "object": "model",
#       "created": 1698785189,
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-4o-realtime-preview",
#       "object": "model",
#       "created": 1727659998,
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-4o-realtime-preview-2024-10-01",
#       "object": "model",
#       "created": 1727131766,
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-4o-audio-preview-2024-10-01",
#       "object": "model",
#       "created": 1727389042,
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-4o-audio-preview",
#       "object": "model",
#       "created": 1727460443,
#       "owned_by": "system"
#     },
#     {
#       "id": "tts-1-hd",
#       "object": "model",
#       "created": 1699046015,
#       "owned_by": "system"
#     },
#     {
#       "id": "tts-1-hd-1106",
#       "object": "model",
#       "created": 1699053533,
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-4-1106-preview",
#       "object": "model",
#       "created": 1698957206,
#       "owned_by": "system"
#     },
#     {
#       "id": "text-embedding-ada-002",
#       "object": "model",
#       "created": 1671217299,
#       "owned_by": "openai-internal"
#     },
#     {
#       "id": "gpt-3.5-turbo-16k",
#       "object": "model",
#       "created": 1683758102,
#       "owned_by": "openai-internal"
#     },
#     {
#       "id": "gpt-4o-mini-2024-07-18",
#       "object": "model",
#       "created": 1721172717,
#       "owned_by": "system"
#     },
#     {
#       "id": "text-embedding-3-small",
#       "object": "model",
#       "created": 1705948997,
#       "owned_by": "system"
#     },
#     {
#       "id": "text-embedding-3-large",
#       "object": "model",
#       "created": 1705953180,
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-3.5-turbo-1106",
#       "object": "model",
#       "created": 1698959748,
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-4-0613",
#       "object": "model",
#       "created": 1686588896,
#       "owned_by": "openai"
#     },
#     {
#       "id": "gpt-4-turbo-preview",
#       "object": "model",
#       "created": 1706037777,
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-4-0125-preview",
#       "object": "model",
#       "created": 1706037612,
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-4",
#       "object": "model",
#       "created": 1687882411,
#       "owned_by": "openai"
#     },
#     {
#       "id": "gpt-3.5-turbo-instruct-0914",
#       "object": "model",
#       "created": 1694122472,
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-4o-2024-08-06",
#       "object": "model",
#       "created": 1722814719,
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-4o",
#       "object": "model",
#       "created": 1715367049,
#       "owned_by": "system"
#     }
#   ]
# }

# %%
# but i want to only see tha data
openai.Model.list()['data']
# Out:
# [<Model model id=gpt-4-turbo at 0x1e6db0d9220> JSON: {
#    "id": "gpt-4-turbo",
#    "object": "model",
#    "created": 1712361441,
#    "owned_by": "system"
#  },
#  <Model model id=gpt-4-turbo-2024-04-09 at 0x1e6db0d8140> JSON: {
#    "id": "gpt-4-turbo-2024-04-09",
#    "object": "model",
#    "created": 1712601677,
#    "owned_by": "system"
#  },
#  <Model model id=tts-1 at 0x1e6db0d89b0> JSON: {
#    "id": "tts-1",
#    "object": "model",
#    "created": 1681940951,
#    "owned_by": "openai-internal"
#  },
#  <Model model id=tts-1-1106 at 0x1e6db0d8a50> JSON: {
#    "id": "tts-1-1106",
#    "object": "model",
#    "created": 1699053241,
#    "owned_by": "system"
#  },
#  <Model model id=chatgpt-4o-latest at 0x1e6db0d8370> JSON: {
#    "id": "chatgpt-4o-latest",
#    "object": "model",
#    "created": 1723515131,
#    "owned_by": "system"
#  },
#  <Model model id=dall-e-2 at 0x1e6db0d8050> JSON: {
#    "id": "dall-e-2",
#    "object": "model",
#    "created": 1698798177,
#    "owned_by": "system"
#  },
#  <Model model id=whisper-1 at 0x1e6db0d90e0> JSON: {
#    "id": "whisper-1",
#    "object": "model",
#    "created": 1677532384,
#    "owned_by": "openai-internal"
#  },
#  <Model model id=gpt-3.5-turbo-instruct at 0x1e6db0d9450> JSON: {
#    "id": "gpt-3.5-turbo-instruct",
#    "object": "model",
#    "created": 1692901427,
#    "owned_by": "system"
#  },
#  <Model model id=gpt-4o-mini at 0x1e6db0d94a0> JSON: {
#    "id": "gpt-4o-mini",
#    "object": "model",
#    "created": 1721172741,
#    "owned_by": "system"
#  },
#  <Model model id=gpt-4o-2024-05-13 at 0x1e6db0d94f0> JSON: {
#    "id": "gpt-4o-2024-05-13",
#    "object": "model",
#    "created": 1715368132,
#    "owned_by": "system"
#  },
#  <Model model id=gpt-3.5-turbo at 0x1e6db0d9540> JSON: {
#    "id": "gpt-3.5-turbo",
#    "object": "model",
#    "created": 1677610602,
#    "owned_by": "openai"
#  },
#  <Model model id=gpt-3.5-turbo-0125 at 0x1e6db0d9590> JSON: {
#    "id": "gpt-3.5-turbo-0125",
#    "object": "model",
#    "created": 1706048358,
#    "owned_by": "system"
#  },
#  <Model model id=babbage-002 at 0x1e6db0d95e0> JSON: {
#    "id": "babbage-002",
#    "object": "model",
#    "created": 1692634615,
#    "owned_by": "system"
#  },
#  <Model model id=davinci-002 at 0x1e6daddf0c0> JSON: {
#    "id": "davinci-002",
#    "object": "model",
#    "created": 1692634301,
#    "owned_by": "system"
#  },
#  <Model model id=dall-e-3 at 0x1e6d937cd20> JSON: {
#    "id": "dall-e-3",
#    "object": "model",
#    "created": 1698785189,
#    "owned_by": "system"
#  },
#  <Model model id=gpt-4o-realtime-preview at 0x1e6db0cfde0> JSON: {
#    "id": "gpt-4o-realtime-preview",
#    "object": "model",
#    "created": 1727659998,
#    "owned_by": "system"
#  },
#  <Model model id=gpt-4o-realtime-preview-2024-10-01 at 0x1e6db0cfca0> JSON: {
#    "id": "gpt-4o-realtime-preview-2024-10-01",
#    "object": "model",
#    "created": 1727131766,
#    "owned_by": "system"
#  },
#  <Model model id=gpt-4o-audio-preview-2024-10-01 at 0x1e6db0cfc50> JSON: {
#    "id": "gpt-4o-audio-preview-2024-10-01",
#    "object": "model",
#    "created": 1727389042,
#    "owned_by": "system"
#  },
#  <Model model id=gpt-4o-audio-preview at 0x1e6db0cfc00> JSON: {
#    "id": "gpt-4o-audio-preview",
#    "object": "model",
#    "created": 1727460443,
#    "owned_by": "system"
#  },
#  <Model model id=tts-1-hd at 0x1e6d938a530> JSON: {
#    "id": "tts-1-hd",
#    "object": "model",
#    "created": 1699046015,
#    "owned_by": "system"
#  },
#  <Model model id=tts-1-hd-1106 at 0x1e6d9388be0> JSON: {
#    "id": "tts-1-hd-1106",
#    "object": "model",
#    "created": 1699053533,
#    "owned_by": "system"
#  },
#  <Model model id=gpt-4-1106-preview at 0x1e6d93884b0> JSON: {
#    "id": "gpt-4-1106-preview",
#    "object": "model",
#    "created": 1698957206,
#    "owned_by": "system"
#  },
#  <Model model id=text-embedding-ada-002 at 0x1e6d938a3a0> JSON: {
#    "id": "text-embedding-ada-002",
#    "object": "model",
#    "created": 1671217299,
#    "owned_by": "openai-internal"
#  },
#  <Model model id=gpt-3.5-turbo-16k at 0x1e6d938bd40> JSON: {
#    "id": "gpt-3.5-turbo-16k",
#    "object": "model",
#    "created": 1683758102,
#    "owned_by": "openai-internal"
#  },
#  <Model model id=gpt-4o-mini-2024-07-18 at 0x1e6d938bcf0> JSON: {
#    "id": "gpt-4o-mini-2024-07-18",
#    "object": "model",
#    "created": 1721172717,
#    "owned_by": "system"
#  },
#  <Model model id=text-embedding-3-small at 0x1e6db0d9720> JSON: {
#    "id": "text-embedding-3-small",
#    "object": "model",
#    "created": 1705948997,
#    "owned_by": "system"
#  },
#  <Model model id=text-embedding-3-large at 0x1e6db0d9630> JSON: {
#    "id": "text-embedding-3-large",
#    "object": "model",
#    "created": 1705953180,
#    "owned_by": "system"
#  },
#  <Model model id=gpt-3.5-turbo-1106 at 0x1e6db0d97c0> JSON: {
#    "id": "gpt-3.5-turbo-1106",
#    "object": "model",
#    "created": 1698959748,
#    "owned_by": "system"
#  },
#  <Model model id=gpt-4-0613 at 0x1e6db0d9810> JSON: {
#    "id": "gpt-4-0613",
#    "object": "model",
#    "created": 1686588896,
#    "owned_by": "openai"
#  },
#  <Model model id=gpt-4-turbo-preview at 0x1e6db0d9860> JSON: {
#    "id": "gpt-4-turbo-preview",
#    "object": "model",
#    "created": 1706037777,
#    "owned_by": "system"
#  },
#  <Model model id=gpt-4-0125-preview at 0x1e6db0d98b0> JSON: {
#    "id": "gpt-4-0125-preview",
#    "object": "model",
#    "created": 1706037612,
#    "owned_by": "system"
#  },
#  <Model model id=gpt-4 at 0x1e6db0d9900> JSON: {
#    "id": "gpt-4",
#    "object": "model",
#    "created": 1687882411,
#    "owned_by": "openai"
#  },
#  <Model model id=gpt-3.5-turbo-instruct-0914 at 0x1e6db0d9950> JSON: {
#    "id": "gpt-3.5-turbo-instruct-0914",
#    "object": "model",
#    "created": 1694122472,
#    "owned_by": "system"
#  },
#  <Model model id=gpt-4o-2024-08-06 at 0x1e6db0d99a0> JSON: {
#    "id": "gpt-4o-2024-08-06",
#    "object": "model",
#    "created": 1722814719,
#    "owned_by": "system"
#  },
#  <Model model id=gpt-4o at 0x1e6db0d99f0> JSON: {
#    "id": "gpt-4o",
#    "object": "model",
#    "created": 1715367049,
#    "owned_by": "system"
#  }]

# %%
import pandas as pd

# %%
# see as Data frame
pd.DataFrame(openai.Model.list()['data'])
# Out:
#                                     id object     created         owned_by
# 0                          gpt-4-turbo  model  1712361441           system
# 1               gpt-4-turbo-2024-04-09  model  1712601677           system
# 2                                tts-1  model  1681940951  openai-internal
# 3                           tts-1-1106  model  1699053241           system
# 4                    chatgpt-4o-latest  model  1723515131           system
# 5                             dall-e-2  model  1698798177           system
# 6                            whisper-1  model  1677532384  openai-internal
# 7               gpt-3.5-turbo-instruct  model  1692901427           system
# 8                          gpt-4o-mini  model  1721172741           system
# 9                    gpt-4o-2024-05-13  model  1715368132           system
# 10                       gpt-3.5-turbo  model  1677610602           openai
# 11                  gpt-3.5-turbo-0125  model  1706048358           system
# 12                         babbage-002  model  1692634615           system
# 13                         davinci-002  model  1692634301           system
# 14                            dall-e-3  model  1698785189           system
# 15             gpt-4o-realtime-preview  model  1727659998           system
# 16  gpt-4o-realtime-preview-2024-10-01  model  1727131766           system
# 17     gpt-4o-audio-preview-2024-10-01  model  1727389042           system
# 18                gpt-4o-audio-preview  model  1727460443           system
# 19                            tts-1-hd  model  1699046015           system
# 20                       tts-1-hd-1106  model  1699053533           system
# 21                  gpt-4-1106-preview  model  1698957206           system
# 22              text-embedding-ada-002  model  1671217299  openai-internal
# 23                   gpt-3.5-turbo-16k  model  1683758102  openai-internal
# 24              gpt-4o-mini-2024-07-18  model  1721172717           system
# 25              text-embedding-3-small  model  1705948997           system
# 26              text-embedding-3-large  model  1705953180           system
# 27                  gpt-3.5-turbo-1106  model  1698959748           system
# 28                          gpt-4-0613  model  1686588896           openai
# 29                 gpt-4-turbo-preview  model  1706037777           system
# 30                  gpt-4-0125-preview  model  1706037612           system
# 31                               gpt-4  model  1687882411           openai
# 32         gpt-3.5-turbo-instruct-0914  model  1694122472           system
# 33                   gpt-4o-2024-08-06  model  1722814719           system
# 34                              gpt-4o  model  1715367049           system

# %% [markdown]
# # ChatCompletion API and Completion API
#
# - Completion API: Hooks you up with text completions from a single prompt.
#
# - Chat Completion API: Nails it in the chat game, keeping the conversational flow intact

# %% [markdown]
# # ChatCompletion API

# %%
# Completion API
prompt="Hello,How are you?"

response=openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role":"system","content":"You are a helpful assistant."},
        {"role":"user","content":prompt}
    ]
)

print(response)
# Out:
# {
#   "id": "chatcmpl-ANwP4Hg4Bg08rGa5YbntYKwOhp444",
#   "object": "chat.completion",
#   "created": 1730269410,
#   "model": "gpt-3.5-turbo-0125",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "Hello! I'm here and ready to help you. How can I assist you today?",
#         "refusal": null
#       },
#       "logprobs": null,
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 23,
#     "completion_tokens": 18,
#     "total_tokens": 41,
#     "prompt_tokens_details": {
#       "cached_tokens": 0
#     },
#     "completion_tokens_details": {
#       "reasoning_tokens": 0
#     }
#   },
#   "system_fingerprint": null
# }

# %%
# Completion API
prompt="Hello,How are you?"

response=openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role":"system","content":"You are a helpful assistant."},
        {"role":"user","content":prompt}
    ]
)

print(response["choices"][0]['message']['content'])
# Out:
# Hello! I'm here and ready to assist you. How can I help you today?

# %%
# ChatCompletion API 

prompt1 = "Hello How are you?"
prompt2 = "I am 25 years old & I am a Programmer"
prompt3 = "Tell me about me"

response =openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt1},
        {"role": "user", "content": prompt2},
        {"role": "user", "content": prompt3},
    ]
)

print(response["choices"][0]["message"]["content"])
# Out:
# Based on the information you provided, you are 25 years old and work as a programmer. Is there anything specific you would like to know about yourself?

# %%
# setting the max token

prompt="What is python?"

response=openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role":"system","content":"You are a helpful assistant."},
        {"role":"user","content":prompt}
    ],
    max_tokens=25
)


print(response["choices"][0]['message']['content'])
# Out:
# Python is a high-level, general-purpose programming language known for its readability and simplicity. It is widely used in web development,

# %%
# setting the max token

prompt="What is python?"

response=openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role":"system","content":"You are a helpful assistant."},
        {"role":"user","content":prompt}
    ],
    max_tokens=25
)


print(response)
# Out:
# {
#   "id": "chatcmpl-ANwkClC3VgSKBJFbi6EMaiBJ3tlpS",
#   "object": "chat.completion",
#   "created": 1730270720,
#   "model": "gpt-3.5-turbo-0125",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "Python is a popular high-level programming language known for its readability and simplicity. It is widely used for developing a variety of applications",
#         "refusal": null
#       },
#       "logprobs": null,
#       "finish_reason": "length"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 21,
#     "completion_tokens": 25,
#     "total_tokens": 46,
#     "prompt_tokens_details": {
#       "cached_tokens": 0
#     },
#     "completion_tokens_details": {
#       "reasoning_tokens": 0
#     }
#   },
#   "system_fingerprint": null
# }

# %%
# setting the max token

prompt="What is python?"

response=openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role":"system","content":"You are a helpful assistant."},
        {"role":"user","content":prompt}
    ],
    temperature=0.6
)


print(response["choices"][0]['message']['content'])
# Out:
# Python is a popular high-level, general-purpose programming language known for its simplicity and readability. It supports multiple programming paradigms, including procedural, object-oriented, and functional programming. Python is widely used in web development, data analysis, artificial intelligence, scientific computing, and more. It has a large standard library and a vibrant community, making it a versatile and powerful tool for various applications.

# %%
# setting the max token

prompt="What is python?"

response=openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role":"system","content":"You are a helpful assistant."},
        {"role":"user","content":prompt}
    ],
    temperature=0.6,
    n=2 # how many respinse we want from this
)


print(response)
# Out:
# {
#   "id": "chatcmpl-ANwnJtqWhnwWgK8wKSK85EWw7aPyw",
#   "object": "chat.completion",
#   "created": 1730270913,
#   "model": "gpt-3.5-turbo-0125",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "Python is a popular high-level programming language known for its simplicity and readability. It is widely used in various fields such as web development, data science, artificial intelligence, and more. Python supports multiple programming paradigms and has a large standard library that provides ready-to-use modules and functions for various tasks.",
#         "refusal": null
#       },
#       "logprobs": null,
#       "finish_reason": "stop"
#     },
#     {
#       "index": 1,
#       "message": {
#         "role": "assistant",
#         "content": "Python is a popular high-level programming language known for its readability and simplicity. It is widely used in various fields such as web development, data analysis, artificial intelligence, scientific computing, and more. Python supports multiple programming paradigms and has a large standard library that provides tools and modules for various tasks.",
#         "refusal": null
#       },
#       "logprobs": null,
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 21,
#     "completion_tokens": 122,
#     "total_tokens": 143,
#     "prompt_tokens_details": {
#       "cached_tokens": 0
#     },
#     "completion_tokens_details": {
#       "reasoning_tokens": 0
#     }
#   },
#   "system_fingerprint": null
# }

# %%
# ChatCompletion API 

prompt = "Give me the sentiment of this sentence: This Movie is Amazing!"

response =openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt}
    ],
    temperature = 0.6,
)

print(response["choices"][0]["message"]["content"])
# Out:
# The sentiment of the sentence "This Movie is Amazing!" is positive.

# %%
# ChatCompletion API 

prompt = "Give me hindi transilation of this sentence: This Movie is Amazing!"

response =openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt}
    ],
    temperature = 0.6,
)

print(response["choices"][0]["message"]["content"])
# Out:
# यह फिल्म बहुत शानदार है!

# %%
# ChatCompletion API 

prompt = "Detect the language of this sentence: This Movie is Amazing!"

response =openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt}
    ],
    temperature = 0.6,
)

print(response["choices"][0]["message"]["content"])
# Out:
# The sentence "This Movie is Amazing!" is in English.

# %%
# ChatCompletion API 

prompt = "Give me a Python code to add 2 numbers"

response =openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt}
    ],
    temperature = 0.6,
)

print(response["choices"][0]["message"]["content"])
# Out:
# Certainly! Here is a simple Python code to add two numbers:
#
# ```python
# num1 = 5
# num2 = 10
#
# sum = num1 + num2
#
# print("The sum is:", sum)
# ```
#
# You can replace `num1` and `num2` with any numbers you want to add together.

# %% [markdown]
# # Completion API

# %%
# can pass only one prompt

prompt = "What is Python"
response = openai.Completion.create(
    model = "babbage-002",
    prompt = prompt
)
print(response)
# Out:
# {
#   "id": "cmpl-ANwrA43o9qWn0aezMEUoHy2qyj4PS",
#   "object": "text_completion",
#   "created": 1730271152,
#   "model": "babbage-002",
#   "choices": [
#     {
#       "text": " 3 (Beta). The Benefits of Python 3 | Keyboard Trading Systems Inc",
#       "index": 0,
#       "logprobs": null,
#       "finish_reason": "length"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 3,
#     "completion_tokens": 16,
#     "total_tokens": 19
#   }
# }
